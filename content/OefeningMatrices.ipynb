# %% [markdown]
# # Oefeningen: Matrices
#
# Een matrix schrijven we in python als volgt:<br>
# A = [
#     [1,2,3],
#     [4,5,6],
#     [7,8,9]
# ]
# <br>Een matrix in python is dus een lijst van lijsten.
# Zo is bijvoorbeeld <br>A[0][0] = 1
#
# ## Voorbeeldoefening: Eerste rij
# Opdracht: Vul de functie aan zodat deze de eerste rij van een gegeven matrix print.

# %%
A = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

def PrintEersteRij(matrix):
  return matrix[0]

PrintEersteRij(A)

#Hieronder hoef je niet te kijken, dit om te kijken of je het juist hebt
assert(PrintEersteRij(A)==[1, 2, 3]), "Fout, je print niet de eerste rij"

# %% [markdown]
# # Oefening 1: Som van de eerste rij
#
# Opdracht: Vul de functie aan zodat deze de eerste rij van de gegeven matrix teruggeeft.

# %%
A = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

def SomEersteRij(matrix):
  return
  #TODO: Maak deze functie

print(SomEersteRij(A))

#Hieronder hoef je niet te kijken, dit om te kijken of je het juist hebt
assert(SomEersteRij(A)==6), "Je komt niet op de juiste uitkomst"
# Out:
# 6

# %% [markdown]
# # Oefening 2: Som alle elementen
#
# Opdracht: Vul de functie aan zodat deze som van alle elementen teruggeeft.

# %%
A = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
B = [
    [10,11,12],
    [-1,-2,-3],
    [4,5,6]
]

def SomAlleElementen(matrix):
  return
  #TODO: Maak deze functie

print(SomAlleElementen(A))
print(SomAlleElementen(B))

assert(SomAlleElementen(A)==45), "Bij A kom je iets fout uit, kijk je functie na."
assert(SomAlleElementen(B)==42), "Bij B kom je iets fout uit, kijk je functie na."
# Out:
# None
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[19], line 19
#      16 print(SomAlleElementen(A))
#      17 print(SomAlleElementen(B))
# ---> 19 assert(SomAlleElementen(A)==45), "Bij A kom je iets fout uit, kijk je functie na."
#      20 assert(SomAlleElementen(B)==42), "Bij B kom je iets fout uit, kijk je functie na."
#
# AssertionError: Bij A kom je iets fout uit, kijk je functie na.

# %% [markdown]
# # Oefening 3: Som van de eerste kolom
#
# Opdracht: Vul de functie aan zodat deze de eerste kolom van de gegeven matrix teruggeeft.

# %%
A = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

def SomEersteKolom(matrix):
  return
  #TODO: Maak deze functie

print(SomEersteKolom(A))

#Hieronder hoef je niet te kijken, dit om te kijken of je het juist hebt
assert(SomEersteKolom(A)==12), "Je komt niet op de juiste uitkomst"
# Out:
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[20], line 14
#      11 print(SomEersteKolom(A))
#      13 #Hieronder hoef je niet te kijken, dit om te kijken of je het juist hebt
# ---> 14 assert(SomEersteKolom(A)==12), "Je komt niet op de juiste uitkomst"
#
# AssertionError: Je komt niet op de juiste uitkomst

# %% [markdown]
# # Oefening 4: Som van matrices
#
# Opdracht: Vul de functie aan zodat deze twee matrices optelt.

# %%
A = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
B = [
    [10,11,12],
    [-1,-2,-3],
    [4,5,6]
]

def SomMatrices(matrix1, matrix2):
  return
  #TODO: Maak deze functie

print(SomMatrices(A, B))

assert(SomMatrices(A, B)==[[11, 13, 15], [3, 3, 3], [11, 13, 15]]), "Fout, je komt niet de juiste uitkomst uit."
# Out:
# None
